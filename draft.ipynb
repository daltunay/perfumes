# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

df = pd.read_csv("assets/products.csv")

# %%
df
# Out:
#                        slug  \
# 0               iso-e-super
# 1                   hedione
# 2        perfumer-s-alcohol
# 3               bergamot-bf
# 4               ambroxan-10
# ..                      ...
# 660         decenal-4-trans
# 661               citrolate
# 662  cis-3-hexenyl-benzoate
# 663           bergamot-mint
# 664       2-tridecenal-neat
#
#                                                    url  \
# 0            https://pellwall.com/products/iso-e-super
# 1                https://pellwall.com/products/hedione
# 2     https://pellwall.com/products/perfumer-s-alcohol
# 3            https://pellwall.com/products/bergamot-bf
# 4            https://pellwall.com/products/ambroxan-10
# ..                                                 ...
# 660      https://pellwall.com/products/decenal-4-trans
# 661            https://pellwall.com/products/citrolate
# 662  https://pellwall.com/products/cis-3-hexenyl-be...
# 663        https://pellwall.com/products/bergamot-mint
# ...
