# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

from llm_scraper.url import *

all_slugs = get_all_slugs()

# %%
for slug in all_slugs:
    try:
        infos = extract_infos_from_slug(slug)
    except Exception as e:
        print(f"Error with {slug}: {e}")
        continue
    print(json.dumps(infos, indent=4))
# Out:
# Velvety, woody, dry, ambergris, old-wood, lemony. Extremely diffusive.
# {
#     "product_name": "Iso E Super",
#     "product_url": "https://pellwall.com/products/iso-e-super",
#     "product_slug": "iso-e-super",
#     "product_type": "liquid",
#     "product_tags": [
#         "ambergris",
#         "aroma-chemicals",
#         "dry",
#         "fixatives",
#         "ingredients-for-perfumery",
#         "lemon",
#         "liquids",
#         "molecules",
#         "old-wood",
#         "velvety",
#         "woody"
#     ],
#     "cas_no": [
#         "54464-57-2"
#     ],
#     "odour": [
#         "velvety",
#         "woody",
#         "dry",
#         "ambergris",
#         "old-wood",
#         "lemony"
#     ],
#     "solvent": "",
#     "synonyms": [
#         "otne",
#         "octahydrotetramethyl acetophenone",
#         "patchouli ethanone",
#         "tetramethyl acetyloctahydronaphthalenes"
#     ],
#     "manufacturer": "IFF"
# }
# ...
